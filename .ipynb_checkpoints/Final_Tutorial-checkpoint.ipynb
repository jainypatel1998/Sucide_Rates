# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# Importing the data and looking at it.
df = pd.read_csv("master.csv", sep=',')
display(df.describe())
display(df)
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# max        0.944000       126352.000000
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# 0                   6.71     Albania1987           NaN      2,156,624,900
# 1                   5.19     Albania1987           NaN      2,156,624,900
# 2                   4.83     Albania1987           NaN      2,156,624,900
# 3                   4.59     Albania1987           NaN      2,156,624,900
# 4                   3.28     Albania1987           NaN      2,156,624,900
# ...                  ...             ...           ...                ...
# 27815               2.96  Uzbekistan2014         0.675     63,067,077,179
# 27816               2.58  Uzbekistan2014         0.675     63,067,077,179
# 27817               2.17  Uzbekistan2014         0.675     63,067,077,179
# 27818               1.67  Uzbekistan2014         0.675     63,067,077,179
# 27819               1.46  Uzbekistan2014         0.675     63,067,077,179
#
#        gdp_per_capita ($)       generation
# 0                     796     Generation X
# 1                     796           Silent
# 2                     796     Generation X
# 3                     796  G.I. Generation
# 4                     796          Boomers
# ...                   ...              ...
# 27815                2309     Generation X
# 27816                2309           Silent
# 27817                2309     Generation Z
# 27818                2309     Generation Z
# 27819                2309          Boomers
#
# [27820 rows x 12 columns]

# %%
# EDA 1
# processing data to group by year
a =df.groupby(['year']).sum().reset_index()
display(a)
# Year vs numb
plt.plot(a['year'],a['suicides_no'])
# looking at the plot \, suicide rates in 2016 are unrealisitcally low, as well as population. 
# Must be incomplete data - > Disregarding the year 2016
is_not_2016 =  df['year']!=2016
df = df[is_not_2016]
display(df.describe())
# Out:
#     year  suicides_no  population  suicides/100k pop  HDI for year  \
# 0   1985       116063  1008600086            6811.89       310.428
# 1   1986       120670  1029909613            6579.84         0.000
# 2   1987       126842  1095029726            7545.45         0.000
# 3   1988       121026  1054094424            7473.13         0.000
# 4   1989       160244  1225514347            8036.54         0.000
# 5   1990       193361  1466620100            9878.75       429.480
# 6   1991       198020  1489988384           10321.06         0.000
# 7   1992       211473  1569539447           10528.88         0.000
# 8   1993       221565  1530416654           10790.29         0.000
# 9   1994       232063  1548749372           11483.79         0.000
# 10  1995       243544  1591559103           14660.26       556.740
# 11  1996       246725  1662267662           14142.21         0.000
# 12  1997       240745  1702991519           13817.83         0.000
# 13  1998       249591  1725181351           14150.72         0.000
# 14  1999       256119  1776363155           14473.91         0.000
# 15  2000       255832  1799227908           14387.45       686.700
# 16  2001       250652  1755565489           14276.21         0.000
# 17  2003       256079  1838458020           13627.58         0.000
# 18  2004       240861  1745246613           12581.80         0.000
# 19  2005       234375  1734909645           12164.99       710.844
# 20  2006       233361  1840908837           12166.01         0.000
# 21  2007       233408  1859564353           12410.15         0.000
# 22  2008       235447  1860620851           12145.84         0.000
# 23  2009       243487  1976228366           12176.04         0.000
# 24  2010       238702  1997297329           11843.99       800.220
# 25  2011       236484  1993362332           11367.84       773.496
# 26  2012       230160  1912812088           11101.91       753.036
# 27  2013       223199  1890161710           10663.64       746.880
# 28  2014       222984  1912057309           10306.73       727.668
# 29  2015       203640  1774657932            8253.99         0.000
# 30  2016        15603   132101896            2147.39         0.000
#
#     gdp_per_capita ($)
# 0              3508548
# 1              4104636
# 2              5645760
# 3              5870508
# 4              6068424
# 5              7531260
# 6              7782096
# 7              8195232
# 8              8231796
# 9              9438756
# 10            11858508
# 11            11600736
# 12            11398596
# 13            11506728
# 14            12780864
# 15            12865476
# 16            12677892
# 17            15187104
# 18            17895936
# 19            20317212
# 20            21563784
# 21            24709620
# 22            26936208
# 23            24145248
# 24            25193196
# 25            26936148
# 26            26058300
# 27            26911368
# 28            25665252
# 29            19516008
# 30             4106420
#                year   suicides_no    population  suicides/100k pop  \
# count  26628.000000  26628.000000  2.662800e+04       26628.000000
# mean    2001.141055    243.229758  1.853985e+06          12.774851
# std        8.578744    900.594151  3.923961e+06          18.906492
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1994.000000      3.000000  9.790000e+04           0.910000
# 50%     2001.000000     25.000000  4.314125e+05           5.960000
# 75%     2009.000000    132.000000  1.492631e+06          16.570000
# max     2015.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        26628.000000
# mean       0.776601        16978.413700
# std        0.093367        19032.345371
# min        0.483000          251.000000
# 25%        0.713000         3487.000000
# 50%        0.779000         9431.000000
# 75%        0.855000        24922.000000
# max        0.944000       126352.000000

# %%
a =df.groupby(['year']).sum().reset_index()
display(a)
# Year vs numb
plt.plot(a['year'],a['suicides_no'])
# Out:
#     year  suicides_no  population  suicides/100k pop  HDI for year  \
# 0   1985       116063  1008600086            6811.89       310.428
# 1   1986       120670  1029909613            6579.84         0.000
# 2   1987       126842  1095029726            7545.45         0.000
# 3   1988       121026  1054094424            7473.13         0.000
# 4   1989       160244  1225514347            8036.54         0.000
# 5   1990       193361  1466620100            9878.75       429.480
# 6   1991       198020  1489988384           10321.06         0.000
# 7   1992       211473  1569539447           10528.88         0.000
# 8   1993       221565  1530416654           10790.29         0.000
# 9   1994       232063  1548749372           11483.79         0.000
# 10  1995       243544  1591559103           14660.26       556.740
# 11  1996       246725  1662267662           14142.21         0.000
# 12  1997       240745  1702991519           13817.83         0.000
# 13  1998       249591  1725181351           14150.72         0.000
# 14  1999       256119  1776363155           14473.91         0.000
# 15  2000       255832  1799227908           14387.45       686.700
# 16  2001       250652  1755565489           14276.21         0.000
# 17  2003       256079  1838458020           13627.58         0.000
# 18  2004       240861  1745246613           12581.80         0.000
# 19  2005       234375  1734909645           12164.99       710.844
# 20  2006       233361  1840908837           12166.01         0.000
# 21  2007       233408  1859564353           12410.15         0.000
# 22  2008       235447  1860620851           12145.84         0.000
# 23  2009       243487  1976228366           12176.04         0.000
# 24  2010       238702  1997297329           11843.99       800.220
# 25  2011       236484  1993362332           11367.84       773.496
# 26  2012       230160  1912812088           11101.91       753.036
# 27  2013       223199  1890161710           10663.64       746.880
# 28  2014       222984  1912057309           10306.73       727.668
# 29  2015       203640  1774657932            8253.99         0.000
#
#     gdp_per_capita ($)
# 0              3508548
# 1              4104636
# 2              5645760
# 3              5870508
# 4              6068424
# 5              7531260
# 6              7782096
# 7              8195232
# 8              8231796
# 9              9438756
# 10            11858508
# 11            11600736
# 12            11398596
# 13            11506728
# 14            12780864
# 15            12865476
# 16            12677892
# 17            15187104
# 18            17895936
# 19            20317212
# 20            21563784
# 21            24709620
# 22            26936208
# 23            24145248
# 24            25193196
# 25            26936148
# 26            26058300
# 27            26911368
# 28            25665252
# 29            19516008

# %%
# EDA 2:
# Comparing the GDP and suicides per 100
plt.scatter(df['gdp_per_capita ($)'],df['suicides/100k pop'])

# %%
# EDA 3
##Top countries that have the most suicide rates
#----------------------------------------------
#group by based on countries
groupByCountry = df.groupby(['country']).sum().reset_index()
#sort based on suicide rates
groupByCountry = groupByCountry.sort_values(by=['suicides/100k pop'])
groupByCountry = groupByCountry.tail(20)
#plot country vs. suicide rate compared with population size
ax = groupByCountry.plot.bar(x='country',y='suicides/100k pop', rot=0, figsize=(25,5))

# %%
# EDA 4
# Plot Generations Vs. Suicide Number
#---------------------------------------------
#group by based on generation type
groupByGen = df.groupby(['generation']).sum().reset_index()
#plot generation vs. suicides_no
ax = groupByGen.plot.bar(x='generation', y = 'suicides_no', rot=0, figsize=(15,5))
